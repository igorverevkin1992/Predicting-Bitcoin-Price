# %%
import pandas as pd
import os
import glob

# %%
path = 'D:\Tutorials\SDST\My Projects\Capstone3\datasets'
all_tokens = glob.glob(os.path.join(path, '*.csv'))
df = pd.concat([pd.read_csv(t) for t in all_tokens])

# %%
prefixes = ['BTC', 'ETH', 'DOT', 'XRP', 'ADA', 'LINK', 'LTC', 'XLM', 'XMR', 'XTZ']
for p in prefixes:
    df = df.add_prefix(p)

# %%
df
# Out:
#      XTZXMRXLMLTCLINKADAXRPDOTETHBTCDate  XTZXMRXLMLTCLINKADAXRPDOTETHBTCOpen  \
# 0                             2020-12-12                             18051.32
# 1                             2020-12-11                             18263.93
# 2                             2020-12-10                             18553.30
# 3                             2020-12-09                             18320.88
# 4                             2020-12-08                             19191.53
# ...                                  ...                                  ...
# 2780                          2013-05-03                                 3.39
# 2781                          2013-05-02                                 3.78
# 2782                          2013-05-01                                 4.29
# 2783                          2013-04-30                                 4.40
# 2784                          2013-04-29                                 4.37
#
# ...

# %%
df_bitcoin = pd.read_csv('../datasets/1.bitcoin.csv')
df_bitcoin.head()
df_bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2785 entries, 0 to 2784
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2785 non-null   object
#  1   Open        2785 non-null   float64
#  2   High        2785 non-null   float64
#  3   Low         2785 non-null   float64
#  4   Close       2785 non-null   float64
#  5   Volume      2785 non-null   float64
#  6   Market Cap  2785 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 152.4+ KB

# %%
df_eth = pd.read_csv('../datasets/2.ethereum.csv')
df_eth.head()
df_eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955 entries, 0 to 1954
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1955 non-null   object
#  1   Open        1955 non-null   float64
#  2   High        1955 non-null   float64
#  3   Low         1955 non-null   float64
#  4   Close       1955 non-null   float64
#  5   Volume      1955 non-null   float64
#  6   Market Cap  1955 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 107.0+ KB

# %%
df_1 = pd.concat([pd.read_csv(t) for t in all_tokens], axis=1)

# %%
df_1
# Out:
#             Date      Open      High       Low     Close        Volume  \
# 0     2020-12-12  18051.32  18919.55  18046.04  18803.66  2.175258e+10
# 1     2020-12-11  18263.93  18268.45  17619.53  18058.90  2.791964e+10
# 2     2020-12-10  18553.30  18553.30  17957.07  18264.99  2.554713e+10
# 3     2020-12-09  18320.88  18626.29  17935.55  18553.92  3.442037e+10
# 4     2020-12-08  19191.53  19283.48  18269.95  18321.14  3.169229e+10
# ...          ...       ...       ...       ...       ...           ...
# 2780  2013-05-03    106.25    108.13     79.10     97.75  0.000000e+00
# 2781  2013-05-02    116.38    125.60     92.28    105.21  0.000000e+00
# 2782  2013-05-01    139.00    139.89    107.72    116.99  0.000000e+00
# 2783  2013-04-30    144.00    146.93    134.05    139.00  0.000000e+00
# 2784  2013-04-29    134.44    147.49    134.00    144.54  0.000000e+00
#
#         Market Cap        Date      Open      High  ...  Close       Volume  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2020-12-12  18051.320000  18919.550000  18046.040000  18803.660000
# 1    2020-12-11  18263.930000  18268.450000  17619.530000  18058.900000
# 2    2020-12-10  18553.300000  18553.300000  17957.070000  18264.990000
# 3    2020-12-09  18320.880000  18626.290000  17935.550000  18553.920000
# 4    2020-12-08  19191.530000  19283.480000  18269.950000  18321.140000
# ...         ...           ...           ...           ...           ...
# 2683 2013-08-08      0.004397      0.004424      0.004175      0.004254
# 2684 2013-08-07      0.004669      0.004682      0.004333      0.004417
# 2685 2013-08-06      0.005637      0.005661      0.004629      0.004680
# 2686 2013-08-05      0.005875      0.005980      0.005613      0.005613
# 2687 2013-08-04      0.005874      0.005927      0.005874      0.005882
#
#             Volume    Market Cap
# 0     2.175258e+10  3.491706e+11
# 1     2.791964e+10  3.353262e+11
# ...

# %%
all_files = glob.glob(os.path.join(path, '*.csv'))

li = []

for filename in all_files:
    df = pd.read_csv(filename)
    li.append(df)

frame = pd.concat(li, axis=1, keys=[p for p in prefixes])

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2785 entries, 0 to 2784
# Data columns (total 70 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (BTC, Date)         2785 non-null   object
#  1   (BTC, Open)         2785 non-null   float64
#  2   (BTC, High)         2785 non-null   float64
#  3   (BTC, Low)          2785 non-null   float64
#  4   (BTC, Close)        2785 non-null   float64
#  5   (BTC, Volume)       2785 non-null   float64
#  6   (BTC, Market Cap)   2785 non-null   float64
#  7   (ETH, Date)         2322 non-null   object
#  8   (ETH, Open)         2322 non-null   float64
#  9   (ETH, High)         2322 non-null   float64
#  10  (ETH, Low)          2322 non-null   float64
#  11  (ETH, Close)        2322 non-null   float64
#  12  (ETH, Volume)       2322 non-null   float64
#  13  (ETH, Market Cap)   2322 non-null   float64
#  14  (DOT, Date)         2397 non-null   object
# ...
