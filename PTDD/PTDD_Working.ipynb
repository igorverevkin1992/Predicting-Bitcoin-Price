# %% [markdown]
# # CAPSTONE 3. Predicting Major Cryptocurrencies Prices
# ## Preprocessing and Training Data Development

# %% [markdown]
# In this notebook we will perform preprocessing and training data development for the project. The goal of this process is to standardize our model development dataset. <br>
# <br>
# In the previous step we discovered that our Bitcoin pricing process is not stationary - it has a clear trend. We also tested the null hypothesis that Bitcoin pricing process is a random walk, performed Augmented Dickey-Fuller test and based on its results we <b>confidentely rejected</b> this hypothesis. In order to perform time series forecasting we will need to perform next steps:<br>
# <ul>
#     - <i>Remove trend</i><br>
#     - <i>Remove seasonality</i>
# </ul>
# In other words, we will need to <b><i>make our time series stationary</i></b>. Since most of the time series forecasting are based on regression (for real values, like bitcoin price), this is an essential step for getting accurate predictions.
# <br>
# In preprocessing and training data development step we will build and train a baseline model - in this case it will be <b>Autoregressive Integrated Moving Average (ARIMA)</b> - which is a classic model for time series forecasting based on the assumption that previous values carry information about the process and can be used to predict future values. In following steps we will build more models and compare there performance.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
import sklearn.model_selection
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

warnings.filterwarnings('ignore')

#setting default figure size
sns.set(rc={"figure.figsize":(12, 5)})
plt.rcParams['figure.figsize'] = (12, 5)

sns.set_style('whitegrid')

#showing only 2 decimals for floats
pd.options.display.float_format = "{:.3f}".format

# %%
# loading the data
df = pd.read_csv('../EDA/Data_for_PTDD.csv')
df_merged = pd.read_pickle('../EDA/df_merged.pkl')
btc = pd.read_pickle('../EDA/BTC.pkl')
eth = pd.read_pickle('../EDA/ETH.pkl')
xrp = pd.read_pickle('../EDA/XRP.pkl')
ltc = pd.read_pickle('../EDA/LTc.pkl')

# %% [markdown]
# ### TRANSFORMING THE TIME SEREIS

# %% [markdown]
# Since our time series is not stationary, we will need to transform it into stationary one in order to apply machine learning models to it. Let's take a look at BTC price once again.

# %%
sns.lineplot(data=btc, x='Date', y='Close', color='Gold')
plt.title(f'August 2015 - January 2021 BTC price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show();

# %% [markdown]
# Although we don't necessarily see any seasonality, we can clearly see an upward trend. We will apply differencing method to our time-series - a method of removing the series dependence on time, which includes structures like trend and seasonality. Differencing is performed by subtracting the previous observation from the current observation. Pandas provides us with the necessary function.

# %%
BTC_price = btc['Close']
BTC_diff = BTC_price.diff(periods=1)
plt.plot(BTC_diff, color='Gold')
plt.show();

# %% [markdown]
# It looks more stationary now. Let's check it with the ACF plot.

# %%
# plotting BTC_Price ACF
plot_acf(BTC_diff.dropna(), lags=50)
plt.xlabel('Lags')
plt.ylabel('Autocorrelation')
plt.title('BTC price (2015-2021) ACF (differenced)')
plt.show();

# %% [markdown]
# As we would expect for a stationary time series, the autocorrelation values degraded to zero very quickly. The plot confirms that the differencing method made our BTC price series <b>stationary</b>. <br>
# <br>
# <b><i>REMINDER:</i></b> our bitcoin price were collected using <b>daily</b> values. Thus, <b>each lag equals to one day</b>.

# %% [markdown]
# ### ARIMA model

# %% [markdown]
# ARIMA stands for Auto Regressive Integrated Moving Average. As we can see, there are 3 components in this acronym:<br>
# <ol>
#     <ol>1. AR - Auto Regression - relationship between given observation and some lagged observation (or several observations).</ol>
#     <ol>2. I - Integrated - the observations are differenced in order to make a time series stationary</ol>
#     <ol>3. MA - Moving Average - relationship between given observation and a residual error from some lagged observation (or several observations).</ol>
# </ol>
# From those three parts of the model we can conclude that it takes 3 inputs:
# <ol>
#     <ol>1. p - Lag order - the number of lagged observations</ol>
#     <ol>2. d - Degree of differencing - the number of times the observations are differenced</ol>
#     <ol>3. q - Order of moving average - the size of moving average window
# </ol>
# <br>
# Next question is how we can determine what orders should we use for those three inputs. We will use ACF to find out <i>q</i>, and PACF (Partial Autocorrelation Function) to find out <i>p</i>.

# %% [markdown]
# #### MA - Autocorrelation Function (ACF)

# %% [markdown]
# If we look at the graph of the ACF above, we can see that most of the values are withing that blue shaded area, which means they are not statistically difference from zero, and they degrade to zero quickly after the 1st lag. We will start with MA(1) for <i>q</i>

# %% [markdown]
# #### AR - Partial Autocorrelation Function (PACF)

# %% [markdown]
# PACF measures direct effect of some particular lagged observation to the given observation, skipping all the observations between them. Without goint too deep into the details, PACF will help us to determine input <i>p</i> for the Auto Regression part of our model.

# %%
# plotting BTC_price PACF
plot_pacf(BTC_diff.dropna(), lags=50)
plt.xlabel('Lags')
plt.ylabel('Partial Autocorrelation')
plt.title('BTC price (2015-2021) PACF (differenced)')
plt.show();

# %% [markdown]
# Here we can see that 2 observations in the beginning of X-axis that are statistically different from zero. Thus, let's use AR(2) for our <i>p</i>.

# %% [markdown]
# #### I - Differencing

# %% [markdown]
# We already differenced our time series and saw that using 1 as degree of differencing (periods=1) made it stationary. Thus, we will use I(1) for <i>d</i>

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# Now, after we determined inputs for our ARIMA model, we need to split our data into training and testing parts. However, we <b>CAN NOT</b> directly use train_test_split function, because it assumes there is no relationships between observations. In case of time series, this assumption is wrong. Instead, we will divide our time series into 80%-20% train-test split manually.

# %%
BTC_price = BTC_price.sort_values(ascending=True)
BTC_val = BTC_price.values

# %%
# train-test split
train_size = int(len(BTC_val) * 0.8)
train, test = BTC_val[0:train_size], BTC_val[train_size:len(BTC_val)]
print(f'Total Observations: {(len(BTC_val))}')
print(f'Training Observations: {(len(train))}')
print(f'Testing Observations: {(len(test))}')
plt.plot(train)
plt.plot([None for i in train] + [x for x in test])
plt.show()
# Out:
# Total Observations: 1994
# Training Observations: 1595
# Testing Observations: 399

# %% [markdown]
# Now we will normalize our data usning StandardScaler.

# %%
BTC_val = BTC_val.reshape((len(BTC_val), 1))
scaler = StandardScaler()
scaler = scaler.fit(BTC_val)
print(f'Mean: {scaler.mean_}, StandardDeviation: {np.sqrt(scaler.var_)}')
BTC_norm = scaler.transform(BTC_val)
# printing first 5 values of normalized series
for i in range(5):
    print(BTC_norm[i])
# Out:
# Mean: [5992.91720667], StandardDeviation: [5646.50351735]
# [-1.0240713]
# [-1.02396788]
# [-1.022103]
# [-1.02154337]
# [-1.02135529]

# %% [markdown]
# ### Building ARIMA model with predetermined inputs

# %% [markdown]
# Now we will build ARIMA model, train and evaluate it. For our first trial we will use the (p,d,q) order we determined earlier - (2,1,1)

# %%
ARIMA_model = ARIMA(BTC_norm, order = (2,1,1))
ARIMA_fit = ARIMA_model.fit()
ARIMA_errors = pd.DataFrame(ARIMA_fit.resid)
print(ARIMA_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1994
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                5416.300
# Date:                Wed, 07 Jul 2021   AIC                         -10824.600
# Time:                        17:00:48   BIC                         -10802.210
# Sample:                             0   HQIC                        -10816.377
#                                - 1994
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9698      0.005    208.783      0.000       0.961       0.979
# ar.L2          0.0291      0.004      7.311      0.000       0.021       0.037
# ma.L1         -0.8868      0.004   -215.181      0.000      -0.895      -0.879
# sigma2         0.0003   9.86e-07    257.877      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):           4036738.44
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):             460.91   Skew:                            11.98
# Prob(H) (two-sided):                  0.00   Kurtosis:                       222.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# We can see that the first AR coefficient is 0.9698, which means the current time series value is strongly positively correlated with time series values 1 lag before. The second lag has very small correlation, as well as sigma. MA part shows that it has strong negative correlation with a current value. The P-values are all 0, which means all 4 of these coefficients have significant predictive power. <b>!!!???DOES IT REALLY? THEY ARE NOT CLOSE TO ZERO BUT ACTUALLY ZERO!!!???</b>

# %%
print(ARIMA_errors.describe())
sns.scatterplot(data=ARIMA_errors);
# Out:
#              0
# count 1994.000
# mean    -0.000
# std      0.028
# min     -1.024
# 25%     -0.001
# 50%     -0.000
# 75%      0.000
# max      0.341

# %% [markdown]
# It seems like we don't have any trend information not caught by our model, which is a good result.

# %%
sns.kdeplot(data=ARIMA_errors);

# %% [markdown]
# Indeed, the mean of the errors is 0, which indicates there is no structure not caught by the model.

# %% [markdown]
# # СДЕЛАТЬ ПРЕДИКТ ДЛЯ АРИМЫ И ПОСМОТРЕТЬ КАК ОНА РАБОТАЕТ. В МОДЕЛИНГЕ СДЕЛАТЬ ГРИД СЕРЧ ДЛЯ АРИМЫ И ПОСТРОИТЬ ДРУГИЕ МОДЕЛИ.

# %% [markdown]
# ### Predicting future values using ARIMA

# %% [markdown]
# Now, after we fitted the model, we can use it to predict future values of the timeseries. We will use forecast() function on every element of the test set and store them in a list. We will also create a list with train set observations. At the end we will plot the expected values vs predicted values and see how our model did.

# %%
predictions = [] # List where all the predicted values will be stored
observations = [x for x in train] # List with train set values

# %%
for i in range(len(test)):
    ARIMA_model = ARIMA(observations, order=(2,1,1))
    ARIMA_fit = ARIMA_model.fit()
    ARIMA_forecast = ARIMA_fit.forecast()
    ypred = ARIMA_forecast[0]
    predictions.append(ypred)
    exp_val = test[i]
    observations.append(exp_val)
    print(f'Predicted value: {ypred}, expected value :{exp_val}')
# Out:
# Predicted value: 9601.10365052338, expected value :9598.173828
# Predicted value: 9604.604601616236, expected value :9607.423828
# Predicted value: 9614.312652005818, expected value :9608.475586
# Predicted value: 9614.28261370437, expected value :9613.423828
# Predicted value: 9619.235539967636, expected value :9629.658203
# Predicted value: 9637.05433237921, expected value :9630.664063
# Predicted value: 9636.615923322253, expected value :9633.386719
# Predicted value: 9638.981455286881, expected value :9648.717773
# Predicted value: 9655.874033490663, expected value :9650.174805
# Predicted value: 9656.029905744736, expected value :9653.679688
# Predicted value: 9659.290587325324, expected value :9654.799805
# Predicted value: 9659.743417660591, expected value :9656.717773
# Predicted value: 9661.299045643831, expected value :9663.181641
# Predicted value: 9668.113705064172, expected value :9664.730469
# Predicted value: 9669.020821799579, expected value :9665.533203
# Predicted value: 9669.351403221232, expected value :9670.739258
# Predicted value: 9674.854816632213, expected value :9677.113281
# Predicted value: 9681.485665091996, expected value :9686.441406
# Predicted value: 9691.44583667728, expected value :9690.142578
# Predicted value: 9694.707929091062, expected value :9693.802734
# Predicted value: 9698.213620403969, expected value :9697.5
# Predicted value: 9701.782895196833, expected value :9700.414063
# Predicted value: 9704.462377090249, expected value :9700.759766
# Predicted value: 9704.239051534892, expected value :9726.575195
# Predicted value: 9733.581969078521, expected value :9729.038086
# Predicted value: 9734.486008868618, expected value :9729.324219
# Predicted value: 9734.042894588083, expected value :9729.801758
# Predicted value: 9734.000483108935, expected value :9733.72168
# Predicted value: 9737.985268685548, expected value :9743.860352
# Predicted value: 9748.99144333715, expected value :9754.422852
# Predicted value: 9760.122303360857, expected value :9757.970703
# Predicted value: 9763.073396551628, expected value :9758.852539
# Predicted value: 9763.315576281158, expected value :9771.489258
# Predicted value: 9777.305808990817, expected value :9795.700195
# Predicted value: 9804.004576524607, expected value :9795.943359
# Predicted value: 9802.240628646665, expected value :9800.636719
# Predicted value: 9806.871343143344, expected value :9811.925781
# Predicted value: 9818.932183298855, expected value :9813.070313
# Predicted value: 9818.92261078871, expected value :9818.349609
# Predicted value: 9824.245875469165, expected value :9842.666016
# Predicted value: 9851.342941571722, expected value :9856.611328
# Predicted value: 9865.355849358051, expected value :9858.150391
# Predicted value: 9865.470473072925, expected value :9865.119141
# Predicted value: 9872.549219143077, expected value :9870.094727
# Predicted value: 9877.086343813662, expected value :9870.303711
# Predicted value: 9876.261586802277, expected value :9888.610352
# Predicted value: 9896.637731815956, expected value :9889.424805
# Predicted value: 9895.835446881563, expected value :9900.767578
# Predicted value: 9908.090621067433, expected value :9905.166992
# Predicted value: 9911.80110963537, expected value :9911.841797
# Predicted value: 9918.50077084608, expected value :9924.515625
# Predicted value: 9932.017726204807, expected value :9934.433594
# Predicted value: 9942.01160769587, expected value :9951.518555
# Predicted value: 9960.369823502406, expected value :9965.570313
# Predicted value: 9974.784825315692, expected value :10005.0
# Predicted value: 10018.578385000808, expected value :10019.716797
# Predicted value: 10032.25636083019, expected value :10051.704102
# Predicted value: 10067.080906656376, expected value :10058.799805
# Predicted value: 10072.046257891774, expected value :10070.392578
# Predicted value: 10083.485240235526, expected value :10085.62793
# Predicted value: 10098.977664610064, expected value :10106.299805
# Predicted value: 10120.571316363968, expected value :10115.975586
# Predicted value: 10129.131467839112, expected value :10116.673828
# Predicted value: 10127.895258414575, expected value :10131.055664
# Predicted value: 10143.075495382674, expected value :10131.516602
# Predicted value: 10141.533306943356, expected value :10138.049805
# Predicted value: 10147.806391750975, expected value :10138.517578
# Predicted value: 10146.861187515473, expected value :10141.996094
# Predicted value: 10149.811994740165, expected value :10144.556641
# Predicted value: 10151.64365280779, expected value :10159.960938
# Predicted value: 10168.44877799423, expected value :10166.400391
# Predicted value: 10174.195627492629, expected value :10167.268555
# Predicted value: 10173.960182509956, expected value :10169.567383
# Predicted value: 10175.737228616716, expected value :10178.37207
# Predicted value: 10185.040186328208, expected value :10181.641602
# Predicted value: 10187.621825698692, expected value :10185.5
# Predicted value: 10191.193349353282, expected value :10198.248047
# Predicted value: 10205.044772468886, expected value :10208.236328
# Predicted value: 10215.211307508092, expected value :10214.379883
# Predicted value: 10221.027080905602, expected value :10221.099609
# Predicted value: 10227.705031983089, expected value :10225.864258
# Predicted value: 10232.108095884076, expected value :10231.744141
# Predicted value: 10237.922829441992, expected value :10233.599609
# Predicted value: 10239.055233964214, expected value :10233.900391
# Predicted value: 10238.645138288497, expected value :10241.272461
# Predicted value: 10246.55026657239, expected value :10242.347656
# Predicted value: 10246.832964972622, expected value :10245.296875
# Predicted value: 10249.632207170609, expected value :10256.058594
# Predicted value: 10261.392487192104, expected value :10266.415039
# Predicted value: 10272.245200131229, expected value :10276.793945
# Predicted value: 10283.076474720894, expected value :10280.351563
# Predicted value: 10285.976879184704, expected value :10301.099609
# Predicted value: 10309.073537343253, expected value :10311.545898
# Predicted value: 10319.293840856682, expected value :10312.116211
# Predicted value: 10318.562540331077, expected value :10323.755859
# Predicted value: 10331.170743215458, expected value :10326.054688
# Predicted value: 10332.431173359866, expected value :10334.974609
# Predicted value: 10341.836519338285, expected value :10343.106445
# Predicted value: 10350.005165247141, expected value :10345.810547
# Predicted value: 10351.939874963147, expected value :10346.760742
# Predicted value: 10352.165170801003, expected value :10347.712891
# Predicted value: 10352.553138172156, expected value :10353.302734
# Predicted value: 10358.362633740555, expected value :10358.048828
# Predicted value: 10362.982960013911, expected value :10360.546875
# Predicted value: 10365.05908230832, expected value :10363.138672
# Predicted value: 10367.386858000134, expected value :10366.700195
# Predicted value: 10370.862557256538, expected value :10369.563477
# Predicted value: 10373.503878863443, expected value :10370.820313
# Predicted value: 10374.347243480397, expected value :10374.338867
# Predicted value: 10377.916928926637, expected value :10397.900391
# Predicted value: 10404.518843561504, expected value :10399.668945
# Predicted value: 10404.7772547579, expected value :10400.915039
# Predicted value: 10405.510149247017, expected value :10407.964844
# Predicted value: 10413.020638206928, expected value :10410.126953
# Predicted value: 10414.603536220859, expected value :10441.276367
# Predicted value: 10449.867686158852, expected value :10442.170898
# Predicted value: 10448.602884484157, expected value :10462.259766
# Predicted value: 10470.901287291465, expected value :10511.813477
# Predicted value: 10526.257739930003, expected value :10517.254883
# Predicted value: 10528.756677546704, expected value :10518.174805
# Predicted value: 10528.12058100775, expected value :10530.732422
# Predicted value: 10541.33414099422, expected value :10538.459961
# Predicted value: 10548.429820803694, expected value :10551.799805
# Predicted value: 10562.267796972637, expected value :10565.493164
# Predicted value: 10576.230313480715, expected value :10575.533203
# Predicted value: 10585.93335807035, expected value :10583.134766
# Predicted value: 10593.009722864344, expected value :10585.164063
# Predicted value: 10593.82209288521, expected value :10594.493164
# Predicted value: 10603.423726569525, expected value :10599.105469
# Predicted value: 10607.264334068897, expected value :10621.664063
# Predicted value: 10632.070573540834, expected value :10623.330078
# Predicted value: 10631.823068990288, expected value :10623.540039
# Predicted value: 10630.944042595629, expected value :10666.482422
# Predicted value: 10679.428798996165, expected value :10679.136719
# Predicted value: 10690.784275414358, expected value :10680.837891
# Predicted value: 10690.824685666445, expected value :10684.428711
# Predicted value: 10693.658271680264, expected value :10690.400391
# Predicted value: 10699.257608505648, expected value :10701.691406
# Predicted value: 10710.932919737994, expected value :10702.290039
# Predicted value: 10710.053341652943, expected value :10721.327148
# Predicted value: 10730.973984875924, expected value :10725.599609
# Predicted value: 10733.986005964318, expected value :10745.548828
# Predicted value: 10755.725904783385, expected value :10754.4375
# Predicted value: 10763.954865978681, expected value :10763.232422
# Predicted value: 10772.565397755743, expected value :10767.139648
# Predicted value: 10775.585297348478, expected value :10774.426758
# Predicted value: 10782.777674345836, expected value :10779.900391
# Predicted value: 10787.772700716112, expected value :10787.618164
# Predicted value: 10795.472347723313, expected value :10796.951172
# Predicted value: 10804.947996516054, expected value :10801.677734
# Predicted value: 10809.05238367601, expected value :10804.000977
# Predicted value: 10810.640161831427, expected value :10817.155273
# Predicted value: 10824.855298141687, expected value :10821.726563
# Predicted value: 10828.67767150247, expected value :10848.830078
# Predicted value: 10858.79024426461, expected value :10855.371094
# Predicted value: 10864.094512048683, expected value :10868.400391
# Predicted value: 10877.74893270636, expected value :10895.089844
# Predicted value: 10906.78349591985, expected value :10895.830078
# Predicted value: 10905.242834715371, expected value :10912.823242
# Predicted value: 10923.560316142806, expected value :10916.053711
# Predicted value: 10925.362647554863, expected value :10923.62793
# Predicted value: 10932.793713465648, expected value :10931.400391
# Predicted value: 10940.321049653814, expected value :10938.271484
# Predicted value: 10946.837801499918, expected value :10944.585938
# Predicted value: 10952.790431722939, expected value :10948.990234
# Predicted value: 10956.615463075892, expected value :10951.0
# Predicted value: 10957.82965258517, expected value :10970.18457
# Predicted value: 10978.922955632874, expected value :10974.905273
# Predicted value: 10982.605739449094, expected value :10975.599609
# Predicted value: 10982.294770169443, expected value :10978.459961
# Predicted value: 10984.72574779454, expected value :10990.873047
# Predicted value: 10998.091113863042, expected value :11011.102539
# Predicted value: 11019.980340497421, expected value :11053.614258
# Predicted value: 11067.02424712095, expected value :11074.599609
# Predicted value: 11087.902523876583, expected value :11079.46582
# Predicted value: 11091.042697135508, expected value :11086.400391
# Predicted value: 11097.424979718855, expected value :11094.34668
# Predicted value: 11104.961965825083, expected value :11100.467773
# Predicted value: 11110.406688368403, expected value :11111.213867
# Predicted value: 11121.33303770057, expected value :11112.700195
# Predicted value: 11121.387143209162, expected value :11171.400391
# Predicted value: 11187.727665225511, expected value :11182.806641
# Predicted value: 11196.626509101814, expected value :11188.599609
# Predicted value: 11201.177031991536, expected value :11205.892578
# Predicted value: 11219.303561736251, expected value :11208.550781
# Predicted value: 11220.101858545944, expected value :11215.4375
# Predicted value: 11226.520584399344, expected value :11225.299805
# Predicted value: 11236.25316376474, expected value :11246.348633
# Predicted value: 11258.724096268174, expected value :11259.400391
# Predicted value: 11271.430056057075, expected value :11296.361328
# Predicted value: 11311.916172226804, expected value :11296.400391
# Predicted value: 11308.74380616061, expected value :11322.123047
# Predicted value: 11336.72293510028, expected value :11323.200195
# Predicted value: 15871.646791288018, expected value :15838.5
# Predicted value: 15900.973997963963, expected value :15955.587891
# Predicted value: 16026.527643996704, expected value :16068.138672
# Predicted value: 16143.348817926824, expected value :16099.799805
# Predicted value: 16167.441356909183, expected value :16276.34375
# Predicted value: 16359.030328315268, expected value :16317.808594
# Predicted value: 16393.359298101157, expected value :16408.199219
# Predicted value: 16485.89066566855, expected value :16477.599609
# Predicted value: 16554.024472643716, expected value :16564.0
# Predicted value: 16641.57233534549, expected value :16569.400391
# Predicted value: 16638.171506550476, expected value :16624.599609
# Predicted value: 16692.300347639073, expected value :16716.111328
# Predicted value: 16786.748651060723, expected value :16936.800781
# Predicted value: 17025.59148913713, expected value :17108.402344
# Predicted value: 17205.766637161207, expected value :17150.623047
# Predicted value: 17236.482199113896, expected value :17415.400391
# Predicted value: 17526.057719371365, expected value :17429.5
# Predicted value: 17528.685186374994, expected value :17527.0
# Predicted value: 17624.691889183083, expected value :17645.40625
# Predicted value: 17745.09300515465, expected value :17706.900391
# Predicted value: 17803.060669842514, expected value :17717.414063
# Predicted value: 17804.35084881841, expected value :17776.699219
# Predicted value: 17860.5357896618, expected value :17804.005859
# Predicted value: 17881.901896816566, expected value :17817.089844
# Predicted value: 17887.519701496392, expected value :17899.699219
# Predicted value: 17971.963923202446, expected value :18058.904297
# Predicted value: 18141.34384208854, expected value :18177.484375
# Predicted value: 18262.786999774224, expected value :18264.992188
# Predicted value: 18349.755039531767, expected value :18321.144531
# Predicted value: 18402.54245282919, expected value :18364.121094
# Predicted value: 18441.548301383267, expected value :18370.001953
# Predicted value: 18439.358452116507, expected value :18553.916016
# Predicted value: 18637.625910971976, expected value :18621.314453
# Predicted value: 18701.544612221656, expected value :18642.232422
# Predicted value: 18716.258678872935, expected value :18699.765625
# Predicted value: 18772.65971993077, expected value :18732.121094
# Predicted value: 18800.511176629152, expected value :18802.998047
# Predicted value: 18872.114157195603, expected value :18803.65625
# Predicted value: 18864.41749799994, expected value :19107.464844
# Predicted value: 19191.05652689543, expected value :19114.199219
# Predicted value: 19194.393294710393, expected value :19140.800781
# Predicted value: 19215.141533728813, expected value :19142.382813
# Predicted value: 19210.227826035938, expected value :19154.230469
# Predicted value: 19215.993233199846, expected value :19191.630859
# Predicted value: 19250.208120023628, expected value :19201.091797
# Predicted value: 19254.49672157818, expected value :19246.644531
# Predicted value: 19298.289423353315, expected value :19345.121094
# Predicted value: 19401.03075989445, expected value :19417.076172
# Predicted value: 19474.943344153882, expected value :19445.398438
# Predicted value: 19500.71778744797, expected value :19497.400391
# Predicted value: 19551.853567897437, expected value :19625.835938
# Predicted value: 19686.47250261885, expected value :21310.597656
# Predicted value: 21739.353092851066, expected value :22803.082031
# Predicted value: 23930.707585607186, expected value :22805.162109
# Predicted value: 22492.198113115814, expected value :23137.960938
# Predicted value: 23377.88546158158, expected value :23241.345703
# Predicted value: 23205.512065092746, expected value :23477.294922
# Predicted value: 23683.606331804596, expected value :23735.949219
# Predicted value: 23792.007754947186, expected value :23783.029297
# Predicted value: 23853.852160748454, expected value :23869.832031
# Predicted value: 23876.244468183486, expected value :24664.791016
# Predicted value: 25183.620555201855, expected value :26272.294922
# Predicted value: 27275.760492633923, expected value :26437.037109
# Predicted value: 26304.215706987754, expected value :27084.808594
# Predicted value: 27595.015898599133, expected value :27362.4375
# Predicted value: 27325.92752333842, expected value :28840.953125
# Predicted value: 29563.03111907058, expected value :29001.720702999995
# Predicted value: 29431.317419753705, expected value :29374.152344
# Predicted value: 29827.76946203255, expected value :31786.878906
# Predicted value: 32742.155572364954, expected value :31971.914063
# Predicted value: 32685.78929116343, expected value :32127.267577999995
# Predicted value: 32713.449248932167, expected value :32782.023438
# Predicted value: 33387.93215892013, expected value :33922.960938
# Predicted value: 34608.432693684386, expected value :33992.429688
# Predicted value: 34593.1814575761, expected value :35566.65625
# Predicted value: 36239.97359453265, expected value :35791.277344
# Predicted value: 36504.40290007075, expected value :36069.804688
# Predicted value: 36709.95780910572, expected value :36178.140625
# Predicted value: 36752.80210035554, expected value :36630.074219
# Predicted value: 37170.84943697841, expected value :36824.363281
# Predicted value: 37332.20520211107, expected value :36825.367188
# Predicted value: 37255.676344895386, expected value :37316.359375
# Predicted value: 37736.448756710095, expected value :38356.441406
# Predicted value: 38852.277756235795, expected value :39187.328125
# Predicted value: 39731.59773709609, expected value :39371.042969
# Predicted value: 39884.4405961288, expected value :40254.546875
# Predicted value: 40792.64628412992, expected value :40797.609375

# %% [markdown]
# We have our predictions. Now let's fine out the Root Mean Square Error - basically, a standard deviation of the prediction's errors.

# %%
rmse = np.sqrt(mean_squared_error(test, predictions))
print(f'Test split RMSE for ARIMA(2,1,1) is: {round(rmse, 2)}')
# Out:
# Test split RMSE for ARIMA(2,1,1) is: 224.73

# %% [markdown]
# Now let's plot predictions vs residuals

# %%
plt.plot(test, label='Expected')
plt.plot(predictions, label='Predicted', color='red', alpha=0.5)
legend = plt.legend(loc='upper center', shadow=True, fontsize='x-large')
plt.show()

# %% [markdown]
# As we can see from the graph, our ARIMA(2,1,1) model did very well. We can barely see the expected values graph because the predicted values graph is almost identical to it.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this step we prepared out data for model development. We scaled it, split it into training and testing sets, plotted ACF and PACF which allowed us to pick (2,1,1) order for our ARIMA model. We then fitted the model on the training set and predicted values for our test set. Then we calculated MSRE ($224.7) and plotted a graph of Expected vs Predicted values. It turned out our model did quite well with the order we derived from the ACF and PACF.<br>
# In next step we will perform ARIMA hyperparameter tuning and build another model - Facebook Prophet. We will evaluate both of those models and decide which one is better for our purpose.

# %%
# saving the data
datapath = 'D://Prog/SDST/My Projects/Capstone3/PTDD'
if not os.path.exists(datapath):
    os.mkdir(datapath)
datapath_PTDD = os.path.join(datapath, 'Data_for_Modeling.csv')
if not os.path.exists(datapath_PTDD):
    df.to_csv(datapath_PTDD, index=False)
df.to_pickle("./df.pkl")
df_merged.to_pickle("./df_merged.pkl")
filename = 'ARIMA(2,1,1).sav'
pickle.dump(ARIMA_model, open(filename, 'wb'))
np.save("BTC_norm", datapath_PTDD, allow_pickle=True)
np.save("train", datapath_PTDD, allow_pickle=True)
np.save("test", datapath_PTDD, allow_pickle=True)
